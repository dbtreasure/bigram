# %%
# %run -i data_preparation/v4.py
# %run -i model_configuration/v2.py
# %run -i model_training/v4.py
# Out:
# epoch: 0
# epoch: 1
# epoch: 2
# epoch: 3
# epoch: 4
# epoch: 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/Development/bigram/model_training/v4.py in <module>
#      16 for epoch in range(epochs):
#      17     print(f'epoch: {epoch}')
# ---> 18     loss = mini_batch(device, train_loader, train_step_fn)
#      19     losses.append(loss)
#      20
#
# ~/Development/bigram/model_training/v4.py in mini_batch(device, data_loader, stepn_fn)
#       9 def mini_batch(device, data_loader, stepn_fn):
#      10     mini_batch_losses = []
# ---> 11     for x_batch, y_batch in data_loader:
#      12         loss = stepn_fn(x_batch, y_batch)
#      13         mini_batch_losses.append(loss)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     626                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
# ...

# %%
losses
# Out:
# [4.853683948516846,
#  3.8988704681396484,
#  3.2517249584198,
#  3.1820614337921143,
#  3.2704505920410156,
#  3.4693851470947266,
#  3.5928492546081543,
#  3.5306973457336426,
#  3.3933095932006836,
#  3.2017388343811035,
#  3.0500168800354004,
#  3.0208542346954346,
#  3.0730738639831543,
#  3.0722618103027344,
#  3.1025168895721436,
#  3.076007604598999,
#  3.031372308731079,
#  2.967475652694702,
#  2.9138402938842773,
#  2.905684471130371]

# %%
import torch
import torch.optim as optim
import torch.nn as nn
from torch.utils.data import Dataset, TensorDataset, DataLoader
from torch.utils.data.dataset import random_split

# import summary writer from tensorboard
from torch.utils.tensorboard import SummaryWriter

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %%
# use plt to plot the losses and val_losses vs epochs
plt.plot(losses, label='loss')
plt.plot(val_losses, label='val_loss')
plt.legend()
plt.show()

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs
# Out:
#       <iframe id="tensorboard-frame-500b6ce0aa9e8a8e" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-500b6ce0aa9e8a8e");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
def smoothing():
    return 1e-5 * model.W.pow(2).mean()

# truncate the model to 2 decimal places
print(f'{smoothing():.2f}')
# Out:
# 0.00

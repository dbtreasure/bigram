# %%
# %run -i data_preparation/v0.py
# %run -i model_configuration/v0.py
# %run -i model_training/v0.py
# Out:
# 3.879657030105591
# 3.3567168712615967
# 3.0779082775115967
# 2.912031888961792
# 2.822808265686035
# 2.7493796348571777
# 2.7053730487823486
# 2.6590123176574707
# 2.633002758026123
# 2.5994739532470703
# 2.583867073059082
# 2.5580544471740723
# 2.5490293502807617
# 2.528029680252075
# 2.523172616958618
# 2.505286455154419
# 2.5032098293304443
# 2.487494707107544
# 2.4874110221862793
# 2.473306179046631
# 2.474717617034912
# 2.4618453979492188
# 2.464406967163086
# 2.4524900913238525
# 2.4559431076049805
# 2.4447708129882812
# 2.4489171504974365
# 2.4383249282836914
# 2.4430124759674072
# 2.432872772216797
# 2.4379851818084717
# 2.42820143699646
# 2.433649778366089
# 2.424149513244629
# 2.4298675060272217
# 2.4205963611602783
# 2.42653489112854
# 2.417452096939087
# 2.4235739707946777
# 2.4146485328674316
# 2.420924425125122
# 2.412132501602173
# 2.4185397624969482
# 2.4098622798919678
# 2.4163830280303955
# 2.407804489135742
# 2.414423942565918
# 2.4059319496154785
# ...

# %%
# %run -i model_generate/v0.py
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     713             fpath = arg_lst[0]
# --> 714             filename = file_finder(fpath)
#     715         except IndexError:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/IPython/utils/path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'model_generate/v0.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# ~/Development/bigram/model_training/v0.py in <module>
# ----> 1 get_ipython().run_line_magic('run', '-i model_generate/v0.py')
#
# ...
